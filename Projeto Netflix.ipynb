# %% [markdown]
#  ![](https://t.ctcdn.com.br/VdF2W8d2MbUD5pd4fxgj-jCUxWk=/61x35:1178x663/1117x628/smart/i371122.jpeg)

# %% [markdown]
# Netflix é uma provedora global de filmes e séries de televisão via streaming sediada em Los Gatos, Califórnia, e que atualmente possui mais de 220 milhões de assinantes. Fundada em 1997 nos Estados Unidos, a empresa surgiu como um serviço de entrega de DVD pelo correio. A expansão do streaming, disponível nos Estados Unidos a partir de 2007, começou pelo Canadá em 2010. Hoje, mais de 190 países têm acesso à plataforma. Sua primeira websérie original de sucesso foi House of Cards, lançada em 2013.
#
# Hoje em dia, a empresa produz centenas de horas de programação original em diferentes países do mundo, querendo aprimorar-se nas aplicações e em novas programações. Os planos foram apresentados no Mobile World Congress em Barcelona, Espanha.Em setembro de 2016 a empresa anunciou que planeja ter 50% do catálogo composto de produções originais.
#
#
#
#
# [ Dados utilizados ](https://www.kaggle.com/datasets/shivamb/netflix-shows)

# %%
#Importando bibliotecas necessárias

import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

# %%
#Carregando dados

data = pd.read_csv('netflix_titles.csv')

data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
#Analisando ultimas linhas do dataset

data.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
#Observando numero de linhas e colunas

data.shape
# Out:
# (8807, 12)

# %%
##Observando numero de elementos do dataset

data.size
# Out:
# 105684

# %%
# Verificando colunas existentes

data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Observando tipo de dados

data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Informações sobre os tipos das variáveis

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.shape
# Out:
# (8807, 12)

# %%
#Verificando se há dados duplicados


data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
#VErificando dados nulos

data.isnull()
# Out:
#       show_id   type  title  director   cast  country  date_added  \
# 0       False  False  False     False   True    False       False
# 1       False  False  False      True  False    False       False
# 2       False  False  False     False  False     True       False
# 3       False  False  False      True   True     True       False
# 4       False  False  False      True  False    False       False
# ...       ...    ...    ...       ...    ...      ...         ...
# 8802    False  False  False     False  False    False       False
# 8803    False  False  False      True   True     True       False
# 8804    False  False  False     False  False    False       False
# 8805    False  False  False     False  False    False       False
# 8806    False  False  False     False  False    False       False
#
#       release_year  rating  duration  listed_in  description
# 0            False   False     False      False        False
# ...

# %%
#Verificando somatório de dados nulos 

data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#Através do Heatmap ele irá me mostrar de maneira visual onde estão localizados esses dados nulos

sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
#Para mostrar todos os registos de um item em particular em qualquer coluna


data[data['title'].isin(['Stranger Things'])]
# Out:
#      show_id     type            title director  \
# 3685   s3686  TV Show  Stranger Things      NaN
#
#                                                    cast        country  \
# 3685  Winona Ryder, David Harbour, Finn Wolfhard, Mi...  United States
#
#         date_added  release_year rating   duration  \
# 3685  July 4, 2019          2019  TV-14  3 Seasons
#
#                                          listed_in  \
# 3685  TV Horror, TV Mysteries, TV Sci-Fi & Fantasy
#
#                                             description
# 3685  When a young boy vanishes, a small town uncove...

# %%
#Para mostrar todos os registos de um item em particular em qualquer coluna 2

data[data['title'].str.contains('Stranger Things')]
# Out:
#      show_id     type                   title director  \
# 3685   s3686  TV Show         Stranger Things      NaN
# 5200   s5201  TV Show  Beyond Stranger Things      NaN
#
#                                                    cast        country  \
# 3685  Winona Ryder, David Harbour, Finn Wolfhard, Mi...  United States
# 5200  Jim Rash, Matt Duffer, Ross Duffer, Shawn Levy...  United States
#
#             date_added  release_year rating   duration  \
# 3685      July 4, 2019          2019  TV-14  3 Seasons
# 5200  October 27, 2017          2017  TV-14   1 Season
#
#                                               listed_in  \
# 3685       TV Horror, TV Mysteries, TV Sci-Fi & Fantasy
# 5200  Stand-Up Comedy & Talk Shows, TV Mysteries, TV...
#
#                                             description
# 3685  When a young boy vanishes, a small town uncove...
# 5200  Secrets from the "Stranger Things 2" universe ...

# %%
#Verificando o ano de lançamento

data['release_year']
# Out:
# 0       2020
# 1       2021
# 2       2021
# 3       2021
# 4       2021
#         ...
# 8802    2007
# 8803    2018
# 8804    2009
# 8805    2006
# 8806    2015
# Name: release_year, Length: 8807, dtype: int64

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Mudando o tipo de variáveis  para datetime

data['release_year'] = pd.to_numeric(data['release_year'])
data['date_added'] = pd.to_datetime(data['date_added'])

# %%
#Verificando

data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# dtype: object

# %%
#Verficando total de registros por ano

data['date_added'].dt.year.value_counts()
# Out:
# 2019.0    2016
# 2020.0    1879
# 2018.0    1649
# 2021.0    1498
# 2017.0    1188
# 2016.0     429
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: date_added, dtype: int64

# %%
# Visualizando Graficamente maiores registros por ano

data['date_added'].dt.year.value_counts().plot(kind = 'bar')
plt.title('Total de registros por Ano')
plt.xlabel("Ano", size = 13,)
plt.ylabel("Registros", size = 13)
# Out:
# Text(0, 0.5, 'Registros')

# %%
# Total de filmes (TV Show ) e (Movie) há no dataset?
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
# Verificando tipos (TV Show ) e (Movie) 

data.groupby('type').type.count()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
sns.countplot(data['type'])
# Out:
# C:\Users\Cleiton Silva\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
# Vamos observar filmes no ano 2015

data[(data['type'] == 'Movie') & (data['release_year'] == 2015)]
# Out:
#      show_id   type                  title           director  \
# 116     s117  Movie                 Dhanak    Nagesh Kukunoor
# 133     s134  Movie                Chappie     Neill Blomkamp
# 141     s142  Movie             Extraction   Steven C. Miller
# 173     s174  Movie  Snervous Tyler Oakley           Amy Rice
# 257     s258  Movie       O Kadhal Kanmani        Mani Ratnam
# ...      ...    ...                    ...                ...
# 8779   s8780  Movie          Yes or No 2.5  Kirati Nakintanon
# 8784   s8785  Movie   Yoko and His Friends                NaN
# 8788   s8789  Movie           You Carry Me         Ivona Juka
# 8801   s8802  Movie                Zinzana    Majid Al Ansari
# 8806   s8807  Movie                 Zubaan        Mozez Singh
#
#                                                    cast  \
# 116   Krrish Chhabria, Hetal Gada, Vipin Sharma, Gul...
# 133   Sharlto Copley, Hugh Jackman, Sigourney Weaver...
# ...

# %%
# Vamos observar apenas os Títulos de todos os Programas de TV que foram lançados apenas nos Estados Unidos

data[(data['type'] == 'TV Show') & (data['country'] == 'United States')]
# Out:
#      show_id     type                                   title director  \
# 15       s16  TV Show                       Dear White People      NaN
# 40       s41  TV Show  He-Man and the Masters of the Universe      NaN
# 55       s56  TV Show                               Nailed It      NaN
# 67       s68  TV Show                       Saved by the Bell      NaN
# 82       s83  TV Show                                 Lucifer      NaN
# ...      ...      ...                                     ...      ...
# 8710   s8711  TV Show                                   Weeds      NaN
# 8726   s8727  TV Show                    When Calls the Heart      NaN
# 8747   s8748  TV Show                               Winsanity      NaN
# 8755   s8756  TV Show                       Women Behind Bars      NaN
# 8780   s8781  TV Show                            Yo-Kai Watch      NaN
#
#                                                    cast        country  \
# ...

# %%
# Tambem podemos buscar por título

data[(data['type'] == 'TV Show') & (data['country'] == 'United States')] ['title']
# Out:
# 15                           Dear White People
# 40      He-Man and the Masters of the Universe
# 55                                   Nailed It
# 67                           Saved by the Bell
# 82                                     Lucifer
#                          ...
# 8710                                     Weeds
# 8726                      When Calls the Heart
# 8747                                 Winsanity
# 8755                         Women Behind Bars
# 8780                              Yo-Kai Watch
# Name: title, Length: 760, dtype: object

# %%
#Buscando os  top 10 diretores

data['director'].value_counts().head(10)
# Out:
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Youssef Chahine           12
# Jay Chapman               12
# Steven Spielberg          11
# Name: director, dtype: int64

# %%
data.head(3)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
# 2      s3  TV Show             Ganglands  Julien Leclercq
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
# ...

# %%
# Observando quais são as diferentes Classificações definidas pela Netflix

# %%
data['rating'].nunique()
# Out:
# 17

# %%
data['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
# Quantos Filmes obtiveram a classificação 'TV-14' ?

# %%
data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14')].shape
# Out:
# (1427, 12)

# %%
# Quantos Filmes obtiveram a classificação 'TV-14', no Canadá  ?

data[(data['type'] == 'Movie') & (data['rating'] == 'TV-14') & (data['country'] == 'Canada')]
# Out:
#      show_id   type                                        title  \
# 157     s158  Movie                                     Level 16
# 1279   s1280  Movie   Made You Look: A True Story About Fake Art
# 2769   s2770  Movie               There's Something in the Water
# 3424   s3425  Movie  Martin Matte: La vie, la mort...eh la la..!
# 5972   s5973  Movie                             #cats_the_mewvie
# 5973   s5974  Movie                                        #Roxy
# 6192   s6193  Movie                               At First Light
# 6537   s6538  Movie                   Counterfeiting in Suburbia
# 7334   s7335  Movie                            Long Time Running
# 7916   s7917  Movie                   Sadie's Last Days on Earth
# 7936   s7937  Movie                                   Sardaar ji
# 8178   s8179  Movie                  The Accountant of Auschwitz
# 8566   s8567  Movie                         The Wrong Babysitter
#
#                                     director  \
# ...

# %%
#Quantos programas de TV obtiveram a classificação 'R', depois do ano 2010?

data[(data['type'] == 'TV Show') & (data['rating'] == 'R') & (data['release_year'] > 2010)]
# Out:
#      show_id     type                                title           director  \
# 3893   s3894  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
# 7593   s7594  TV Show                                Nobel                NaN
#
#                                                    cast country date_added  \
# 3893  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN 2019-04-25
# 7593  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway 2016-12-10
#
#       release_year rating  duration  \
# 3893          2015      R  1 Season
# 7593          2016      R  1 Season
#
#                                             listed_in  \
# 3893                                         TV Shows
# 7593  International TV Shows, TV Dramas, TV Thrillers
#
#                                             description
# 3893  Trapped at a stagecoach stop as a storm rages ...
# 7593  A series of incidents in Afghanistan set compl...

# %%
data[['Minutes', 'Unit']] = data['duration'].str.split(' ', expand = True)

# %%
# Qual a duração máximo dos programa (TV Show & Movie) da Netflix?

data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
#Tratamento de dados

data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Minutes                 object
# Unit                    object
# dtype: object

# %%
#Tratamento de dados

data['Minutes'] = pd.to_numeric(data['Minutes'])

data.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# Minutes                float64
# Unit                    object
# dtype: object

# %%
data['Minutes'].max()
# Out:
# 312.0

# %%
data['Minutes'].min()
# Out:
# 1.0

# %%
data['Minutes'].mean()
# Out:
# 69.84688777828259

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  Minutes     Unit
# 0  As her father nears the end of his life, filmm...     90.0      min
# 1  After crossing paths at a party, a Cape Town t...      2.0  Seasons

# %%
data_tvshow = data[data['type'] == 'TV Show']

# %%
data_tvshow.head(2)
# Out:
#   show_id     type          title         director  \
# 1      s2  TV Show  Blood & Water              NaN
# 2      s3  TV Show      Ganglands  Julien Leclercq
#
#                                                 cast       country date_added  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa 2021-09-24
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...           NaN 2021-09-24
#
#    release_year rating   duration  \
# 1          2021  TV-MA  2 Seasons
# 2          2021  TV-MA   1 Season
#
#                                            listed_in  \
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
#
#                                          description  Minutes     Unit
# 1  After crossing paths at a party, a Cape Town t...      2.0  Seasons
# 2  To protect his family from a powerful drug lor...      1.0   Season

# %%
#Qual é o país com o maior número de programas de TV ?

data_tvshow.country.value_counts()
# Out:
# United States                                    760
# United Kingdom                                   213
# Japan                                            169
# South Korea                                      158
# India                                             79
#                                                 ...
# Belarus                                            1
# United Kingdom, Australia                          1
# France, Australia, Germany                         1
# Australia, New Zealand, United States              1
# United States, France, South Korea, Indonesia      1
# Name: country, Length: 196, dtype: int64

# %%
data_tvshow.country.value_counts().head(1)
# Out:
# United States    760
# Name: country, dtype: int64

# %%
#Ordenando conjunto de dados por Ano 

data.sort_values(by = 'release_year', ascending = False).head(10)
# Out:
#     show_id     type                                  title          director  \
# 693    s694    Movie                 Ali & Ratu Ratu Queens    Lucky Kuswandi
# 781    s782    Movie  Black Holes | The Edge of All We Know     Peter Galison
# 762    s763    Movie                           Sweet & Sour     Lee Kae-byeok
# 763    s764  TV Show                            Sweet Tooth               NaN
# 764    s765    Movie           Trippin' with the Kandasamys     Jayan Moodley
# 765    s766    Movie                                 Xtreme   Daniel Benmayor
# 766    s767    Movie                Alan Saldaña: Locked Up         Alex Díaz
# 767    s768  TV Show                   Creator's File: GOLD               NaN
# 768    s769    Movie                         Dancing Queens  Helena Bergström
# 770    s771    Movie              Myriam Fares: The Journey      Myriam Fares
#
#                                                   cast               country  \
# ...

# %%
# Concluindo então, uma análise mostrando que se pode extrair diversos tipos de informações
# e manipular de diversas de formas extraindo os dados requeridos
